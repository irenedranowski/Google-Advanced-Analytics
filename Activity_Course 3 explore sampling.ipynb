# %% [markdown]
# # Activity: Explore sampling

# %% [markdown]
# ## Introduction
# In this activity, you will engage in effective sampling of a dataset in order to make it easier to analyze. As a data professional you will often work with extremely large datasets, and utilizing proper sampling techniques helps you improve your efficiency in this work.
#
# For this activity, you are a member of an analytics team for the Environmental Protection Agency. You are assigned to analyze data on air quality with respect to carbon monoxide—a major air pollutant—and report your findings. The data utilized in this activity includes information from over 200 sites, identified by their state name, county name, city name, and local site name. You will use effective sampling within this dataset.

# %% [markdown]
# ## Step 1: Imports

# %% [markdown]
# ### Import packages
#
# Import `pandas`,  `numpy`, `matplotlib`, `statsmodels`, and `scipy`.

# %%
# Import libraries and packages

### YOUR CODE HERE ###
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import scipy

# %% [markdown]
# ### Load the dataset
#
# As shown in this cell, the dataset has been automatically loaded in for you. You do not need to download the .csv file, or provide more code, in order to access the dataset and proceed with this lab. Please continue with this activity by completing the following instructions.

# %%
# RUN THIS CELL TO IMPORT YOUR DATA.

### YOUR CODE HERE ###
epa_data = pd.read_csv("c4_epa_air_quality.csv", index_col = 0)

# %% [markdown]
# <details>
#   <summary><h4>Hint 1</h4></summary>
#
# Use the function in the `pandas` library that allows you to read in data from a csv file and load it into a DataFrame.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4>Hint 2</h4></summary>
#
# Use the `read_csv` function from the pandas `library`. Set the `index_col` parameter to `0` to read in the first column as an index (and to avoid `"Unnamed: 0"` appearing as a column in the resulting Dataframe).
#
# </details>

# %% [markdown]
# ## Step 2: Data exploration

# %% [markdown]
# ### Examine the data
#
# To understand how the dataset is structured, examine the first 10 rows of the data.

# %%
# First 10 rows of the data

### YOUR CODE HERE ###
epa_data.head(10)
# Out:
#    date_local    state_name   county_name      city_name  \
# 0  2018-01-01       Arizona      Maricopa        Buckeye
# 1  2018-01-01          Ohio       Belmont      Shadyside
# 2  2018-01-01       Wyoming         Teton  Not in a city
# 3  2018-01-01  Pennsylvania  Philadelphia   Philadelphia
# 4  2018-01-01          Iowa          Polk     Des Moines
# 5  2018-01-01        Hawaii      Honolulu  Not in a city
# 6  2018-01-01        Hawaii      Honolulu  Not in a city
# 7  2018-01-01  Pennsylvania          Erie           Erie
# 8  2018-01-01        Hawaii      Honolulu       Honolulu
# 9  2018-01-01      Colorado       Larimer   Fort Collins
#
#                                      local_site_name   parameter_name  \
# 0                                            BUCKEYE  Carbon monoxide
# 1                                          Shadyside  Carbon monoxide
# 2  Yellowstone National Park - Old Faithful Snow ...  Carbon monoxide
# ...

# %% [markdown]
# <details>
#   <summary><h4><strong> Hint 1 </STRONG></h4></summary>
#
# Use the function in the `pandas` library that allows you to get a specific number of rows from the top of a DataFrame.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong> Hint 2 </STRONG></h4></summary>
#
# Use the `head` function from the `pandas` library. Set the `n` parameter to `10` to print out the first 10 rows.
#
# </details>

# %% [markdown]
# **Question:** What does the `aqi` column represent?

# %% [markdown]
# The aqi column represents the Air Quality Index for carbon monoxide levels at each location and date in the dataset. In this table, AQI values are calculated from the arithmetic_mean, which measures carbon monoxide concentration in parts per million, and provide a standardized way to interpret how clean or polluted the air is. For example, higher concentrations like 0.994737 ppm in Kapolei, Hawaii correspond to a higher AQI of 14, while lower concentrations like 0.111111 ppm in Yellowstone, Wyoming correspond to a much lower AQI of 2. All values shown (ranging from 2 to 14) fall within the “good” air quality range, indicating minimal health risk, and demonstrate a clear relationship where higher carbon monoxide levels lead to higher AQI values.

# %% [markdown]
# ### Generate a table of descriptive statistics
#
# Generate a table of some descriptive statistics about the data. Specify that all columns of the input be included in the output.

# %%
### YOUR CODE HERE ###
epa_data.describe(include='all')
# Out:
#         date_local  state_name  county_name      city_name local_site_name  \
# count          260         260          260            260             257
# unique           1          52          149            190             253
# top     2018-01-01  California  Los Angeles  Not in a city         Kapolei
# freq           260          66           14             21               2
# mean           NaN         NaN          NaN            NaN             NaN
# std            NaN         NaN          NaN            NaN             NaN
# min            NaN         NaN          NaN            NaN             NaN
# 25%            NaN         NaN          NaN            NaN             NaN
# 50%            NaN         NaN          NaN            NaN             NaN
# 75%            NaN         NaN          NaN            NaN             NaN
# max            NaN         NaN          NaN            NaN             NaN
#
# ...

# %% [markdown]
# <details>
#   <summary><h4>Hint 1</h4></summary>
#
# Use function in the `pandas` library that allows you to generate a table of basic descriptive statistics in a DataFrame.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4>Hint 2</h4></summary>
#
# Use the `describe` function from the `pandas` library. Set the `include` parameter passed in to this function to 'all' to specify that all columns of the input be included in the output.
#
# </details>

# %% [markdown]
# **Question:** Based on the preceding table of descriptive statistics, what is the mean value of the `aqi` column?

# %% [markdown]
# The mean AQI is 6.757692, which I will use later to compare with the mean calculated after sampling with replacement.

# %% [markdown]
# **Question:** Based on the preceding table of descriptive statistics, what do you notice about the count value for the `aqi` column?

# %% [markdown]
# The count for the aqi column is 260, which means all rows have an AQI value and none are missing.

# %% [markdown]
# ### Use the `mean()` function on the `aqi`  column
#
# Now, use the `mean()` function on the `aqi`  column and assign the value to a variable `population_mean`. The value should be the same as the one generated by the `describe()` method in the above table.

# %%
### YOUR CODE HERE ###
population_mean = epa_data['aqi'].mean()
population_mean
# Out:
# 6.757692307692308

# %% [markdown]
# <details>
#   <summary><h4><strong> Hint 1 </STRONG></h4></summary>
#
# Use the function in the `pandas` library that allows you to generate a mean value for a column in a DataFrame.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong> Hint 2 </STRONG></h4></summary>
#
# Use the `mean()` method.
#
# </details>

# %% [markdown]
# ## Step 3: Statistical tests

# %% [markdown]
# ### Sample with replacement
#
# First, name a new variable `sampled_data`. Then, use the `sample()` dataframe method to draw 50 samples from `epa_data`. Set `replace` equal to `'True'` to specify sampling with replacement. For `random_state`, choose an arbitrary number for random seed. Make that arbitrary number `42`.

# %%
### YOUR CODE HERE ###
sampled_data=epa_data.sample(n=50, replace=True, random_state=42)

# %% [markdown]
# ### Output the first 10 rows
#
# Output the first 10 rows of the DataFrame.

# %%
### YOUR CODE HERE ###
sampled_data.head(10)
# Out:
#      date_local      state_name    county_name   city_name  \
# 102  2018-01-01           Texas         Harris     Houston
# 106  2018-01-01      California       Imperial    Calexico
# 71   2018-01-01         Alabama      Jefferson  Birmingham
# 188  2018-01-01         Arizona       Maricopa       Tempe
# 20   2018-01-01        Virginia        Roanoke      Vinton
# 102  2018-01-01           Texas         Harris     Houston
# 121  2018-01-01  North Carolina    Mecklenburg   Charlotte
# 214  2018-01-01         Florida        Broward       Davie
# 87   2018-01-01      California       Humboldt      Eureka
# 99   2018-01-01      California  Santa Barbara      Goleta
#
#                    local_site_name   parameter_name   units_of_measure  \
# 102                        Clinton  Carbon monoxide  Parts per million
# 106          Calexico-Ethel Street  Carbon monoxide  Parts per million
# 71           Arkadelphia/Near Road  Carbon monoxide  Parts per million
# ...

# %% [markdown]
# <details>
#   <summary><h4><strong> Hint 1 </STRONG></h4></summary>
#
# Use the function in the `pandas` library that allows you to get a specific number of rows from the top of a DataFrame.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong> Hint 2 </STRONG></h4></summary>
#
# Use the `head` function from the `pandas` library. Set the `n` parameter to `10` to print out the first 10 rows.
#
# </details>

# %% [markdown]
# **Question:** In the DataFrame output, why is the row index 102 repeated twice?

# %% [markdown]
# The row index 102 appears twice because the data was sampled with replacement.
# This means the same row can be selected more than once during sampling, so its index shows up multiple times in the resulting DataFrame.

# %% [markdown]
# **Question:** What does `random_state` do?

# %% [markdown]
# random_state makes sure I get the same random results every time I run my code by fixing the starting point of the random process. This means the same rows will be selected each time. If I don’t set it, I will get a different random sample each time I run the code.

# %% [markdown]
# ### Compute the mean value from the `aqi` column
#
# Compute the mean value from the `aqi` column in `sampled_data` and assign the value to the variable `sample_mean`.

# %%
### YOUR CODE HERE ###
sample_mean = sampled_data['aqi'].mean()
sample_mean
# Out:
# 5.54

# %% [markdown]
#  **Question:**  Why is `sample_mean` different from `population_mean`?

# %% [markdown]
# The sample mean is different from the population mean because it is based on only part of the data, not all of it. Since the sample is random, it may not match the full dataset exactly.

# %% [markdown]
# ### Apply the central limit theorem
#
# Imagine repeating the the earlier sample with replacement 10,000 times and obtaining 10,000 point estimates of the mean. In other words, imagine taking 10,000 random samples of 50 AQI values and computing the mean for each sample. According to the **central limit theorem**, the mean of a sampling distribution should be roughly equal to the population mean. Complete the following steps to compute the mean of the sampling distribution with 10,000 samples.
#
# * Create an empty list and assign it to a variable called `estimate_list`.
# * Iterate through a `for` loop 10,000 times. To do this, make sure to utilize the `range()` function to generate a sequence of numbers from 0 to 9,999.
# * In each iteration of the loop, use the `sample()` function to take a random sample (with replacement) of 50 AQI values from the population. Do not set `random_state` to a value.
# * Use the list `append()` function to add the value of the sample `mean` to each item in the list.

# %%
### YOUR CODE HERE ###
estimate_list = []
for i in range(10000):
    estimate_list.append(epa_data['aqi'].sample(n=50,replace=True).mean())

# %% [markdown]
# <details>
#   <summary><h4><strong> Hint 1 </STRONG></h4></summary>
#
# Review [the content about sampling in Python](https://www.coursera.org/learn/the-power-of-statistics/lecture/SNOE0/sampling-distributions-with-python).
#
# </details>

# %% [markdown]
# ### Create a new DataFrame
#
# Next, create a new DataFrame from the list of 10,000 estimates. Name the new variable `estimate_df`.

# %%
### YOUR CODE HERE ###
estimate_df = pd.DataFrame(estimate_list,columns=['sample_mean'])
estimate_df
# Out:
#       sample_mean
# 0            6.40
# 1            5.30
# 2            7.94
# 3            7.12
# 4            7.26
# ...           ...
# 9995         7.18
# 9996         6.98
# 9997         6.06
# 9998         7.42
# 9999         4.98
#
# [10000 rows x 1 columns]

# %% [markdown]
# <details>
#   <summary><h4><strong> Hint 1 </STRONG></h4></summary>
#
# Review [the content about sampling in Python](https://www.coursera.org/learn/the-power-of-statistics/lecture/SNOE0/sampling-distributions-with-python).
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong> Hint 2 </STRONG></h4></summary>
#
# Use the `mean()` function.
#
# </details>

# %% [markdown]
# ### Compute the mean() of the sampling distribution
#
# Next, compute the `mean()` of the sampling distribution of 10,000 random samples and store the result in a new variable `mean_sample_means`.

# %%
### YOUR CODE HERE ###
mean_sample_means = estimate_df['sample_mean'].mean()
mean_sample_means
# Out:
# 6.769255999999967

# %% [markdown]
# <details>
#   <summary><h4><strong> Hint 1 </STRONG></h4></summary>
#
# Use the function in the `pandas` library that allows you to generate a mean value for a column in a DataFrame.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong> Hint 2 </STRONG></h4></summary>
#
# Use the `mean()` function.
#
# </details>

# %% [markdown]
# **Question:** What is the mean for the sampling distribution of 10,000 random samples?

# %% [markdown]
# This value may change each time because random_state was not set.

# %% [markdown]
# <details>
#   <summary><h4><strong> Hint 3 </STRONG></h4></summary>
#
# This value is contained in `mean_sample_means`.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong> Hint 4 </STRONG></h4></summary>
#
# According to the central limit theorem, the mean of the preceding sampling distribution should be roughly equal to the population mean.
#
# </details>

# %% [markdown]
# **Question:** How are the central limit theorem and random sampling (with replacement) related?

# %% [markdown]
# The central limit theorem explains what happens when we repeatedly take random samples (with replacement) from a population. By sampling with replacement, we can generate many independent random samples, and when we calculate the mean of each sample, those means form a sampling distribution. The central limit theorem states that this distribution will be approximately normal and its mean will be close to the population mean, even if the original data is not normally distributed.

# %% [markdown]
# ### Output the distribution using a histogram
#
# Output the distribution of these estimates using a histogram. This provides an idea of the sampling distribution.

# %%
### YOUR CODE HERE ###
plt.hist(estimate_df['sample_mean'], bins=30)
plt.xlabel('Sample Mean AQI')
plt.ylabel('Frequency')
plt.title('Sampling Distribution of AQI Means (10,000 Samples)')
plt.show()

# %% [markdown]
# <details>
#   <summary><h4><strong> Hint 1 </STRONG></h4></summary>
#
# Use the `hist()` function.
#
# </details>

# %% [markdown]
# ### Calculate the standard error
#
# Calculate the standard error of the mean AQI using the initial sample of 50. The **standard error** of a statistic measures the sample-to-sample variability of the sample statistic. It provides a numerical measure of sampling variability and answers the question: How far is a statistic based on one particular sample from the actual value of the statistic?

# %%
### YOUR CODE HERE ###
sample_std = sampled_data['aqi'].std()
n = len(sampled_data)

standard_error = sample_std / (n ** 0.5)
standard_error
# Out:
# 0.7413225908290327

# %% [markdown]
# <details>
#   <summary><h4><strong> Hint 1 </STRONG></h4></summary>
#
# Use the `std()` function and the `np.sqrt()` function.
#
# </details>

# %% [markdown]
# ## Step 4: Results and evaluation

# %% [markdown]
# ###  Visualize the relationship between the sampling and normal distributions
#
# Visualize the relationship between your sampling distribution of 10,000 estimates and the normal distribution.
#
# 1. Plot a histogram of the 10,000 sample means
# 2. Add a vertical line indicating the mean of the first single sample of 50
# 3. Add another vertical line indicating the mean of the means of the 10,000 samples
# 4. Add a third vertical line indicating the mean of the actual population

# %%
 ### YOUE CODE HERE ###
plt.hist(estimate_df['sample_mean'], bins=30)

plt.axvline(sample_mean, linestyle='--', label='Sample Mean (n=50)')
plt.axvline(mean_sample_means, linestyle='-', label='Mean of Sample Means')
plt.axvline(epa_data['aqi'].mean(), linestyle=':', label='Population Mean')

plt.xlabel('Sample Mean AQI')
plt.ylabel('Frequency')
plt.title('Sampling Distribution vs Population Mean')

plt.legend()

plt.show()

# %% [markdown]
# **Question:** What insights did you gain from the preceding sampling distribution?

# %% [markdown]
# The sampling distribution is bell-shaped and centered around about 6.7, which is the population mean. Most of the sample means fall between about 5.5 and 8.5, showing that the averages from different samples are usually close to the true mean. The population mean (green solid line) and the mean of the sample means are almost exactly in the same place, showing that the sampling distribution accurately reflects the true average. The single sample mean is slightly lower (around 5.3), which shows that one sample can be off, but many samples together give a much more accurate result.

# %% [markdown]
# # Considerations
#
# **What are some key takeaways that you learned from this lab?**
#
# **What findings would you share with others?**
#
# **What would you convey to external stakeholders?**
#
# Sample means can vary, but when many samples are taken, they form a normal (bell-shaped) distribution centered around the true population mean. The central limit theorem explains this pattern and shows that using many samples leads to more reliable estimates.
#
# The mean of the sample means is very close to the population mean, even though individual sample means may differ. This demonstrates that repeated random sampling produces consistent and accurate results over time.
#
# Even if a single sample appears slightly off, overall trends based on many samples are reliable. Decisions based on aggregated data and repeated sampling are more accurate and representative of the true population.

# %% [markdown]
# **Congratulations!** You've completed this lab. However, you may not notice a green check mark next to this item on Coursera's platform. Please continue your progress regardless of the check mark. Just click on the "save" icon at the top of this notebook to ensure your work has been logged.
